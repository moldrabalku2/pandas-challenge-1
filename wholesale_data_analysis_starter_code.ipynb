# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('../Challenge 4/Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe
# Out:
# <bound method NDFrame.describe of            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
#df
df.dtypes
# Out:
# first           object
# last            object
# job             object
# phone           object
# email           object
# client_id        int64
# order_id         int64
# order_date      object
# order_week       int64
# order_year       int64
# item_id         object
# category        object
# subcategory     object
# unit_price     float64
# unit_cost      float64
# unit_weight    float64
# qty              int64
# line_number      int64
# dtype: object

# %%
# What three item categories had the most entries?
df_count = df['category'].value_counts().head(3)
df_count
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
df_count_sub = df['subcategory'].value_counts().head(1)
df_count_sub
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
df_count_sub = df['client_id'].value_counts().head(5)
df_count_sub
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
df_count_sub_top5 = df_count_sub.index.tolist()
df_count_sub_top5
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
df_qty = df.groupby(["client_id"])[["qty"]].agg('sum')
df_qty.sort_values(by=["qty","client_id", ], ascending=False).head(5)
# Out:
#                qty
# client_id
# 78965      4033302
# 86721      1010426
# 30143       846069
# 85931       644423
# 77354       506382

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df['Subtotal'] = df['unit_price'] * df['qty']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
#unit_price	unit_weight	qty subtotal
#price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.

def shipping_price(scost):
    weight = scost['unit_weight']
    quantity = scost['qty']
    total_weight = weight * quantity

    if total_weight > 50:
        return total_weight * 7
    else:
        return total_weight * 10
    
df['Shipping Price'] = df.apply(shipping_price, axis=1)

# "Apply" the function to the amount column
#donors_df['Match Amount'] = donors_df['Amount'].apply(match_amount)
#donors_df.head()
df['Amount'] = df['Shipping Price'] + df['Subtotal']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
tax_t = df['Amount']*.0925 # Beware of the 0 
Total_Price = tax_t + df['Amount']
df['Total Price'] = Total_Price

df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
 
seller_cost = df['unit_cost'] * df['qty']

df['Sell Cost'] = seller_cost + df['Shipping Price']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the profit of each line using line cost and line price

df['Profit'] = df['Sell Cost'] - df['Subtotal']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
dicts = [{'Order': '2742071', 'total:': '152811.89'},
        {'Order': '2173913', 'total:': '162388.71'},
        {"Order": '6128929','total:': '923441.25'}]

dicts_df = pd.DataFrame(dicts)
dicts_df
# Out:
#      Order     total:
# 0  2742071  152811.89
# 1  2173913  162388.71
# 2  6128929  923441.25

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
#1st part of my flaot format for Total Price
df['Total Price'] = df['Total Price'].astype(float)

sum_df = df[["client_id", "Total Price"]]
#2nd part of my flaot format for Total Price
pd.options.display.float_format = '{:.2f}'.format

sum_df.sort_values(by=["client_id", "Total Price"], ascending=False).head(5)
# Out:
#        client_id  Total Price
# 35379      99984  16257453.17
# 42337      99984   1074078.87
# 4895       99984    501301.35
# 50091      99984    244601.04
# 43411      99984    161957.92

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 
df['Total Price'] = df['Total Price'].astype(float)

sum_df = df[["client_id", "qty", "Shipping Price", "Total Price", "Profit" ]]

pd.options.display.float_format = '{:.2f}'.format

sum_df.sort_values(by=["client_id", "qty", "Shipping Price", "Total Price", "Profit"], ascending=False).head(5)
# Out:
#        client_id    qty  Shipping Price  Total Price      Profit
# 35379      99984  33950      2395512.00  16257453.17 -2092338.50
# 42337      99984   6145       360035.55   1074078.87   194857.95
# 43411      99984   2067        53824.68    161957.92    17342.13
# 958        99984   1647        25594.38     43562.20    21740.40
# 4895       99984    973        12668.46    501301.35  -136589.74

# %%
# Format the data and rename the columns to names suitable for presentation.

# Define the money columns. 


# Define a function that converts a dollar amount to millions.


# Apply the currency_format_millions function to only the money columns. 


# Rename the columns to reflect the change in the money format. 

# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 
df['Total Price'] = df['Total Price'].astype(float)
df['Profit'] = df['Profit'].astype(float)
df['Shipping Price'] = df['Shipping Price'].astype(float)

df['Updated Total Price'] = df['Total Price'].apply(lambda x: f"${x:,.2f}")
df['Updated Profit'] = df['Profit'].apply(lambda x: f"${x:,.2f}")
df['Updated Shipping Price'] = df['Shipping Price'].apply(lambda x: f"${x:,.2f}")

sum_df = df[["client_id", "qty", "Updated Shipping Price", "Updated Total Price", "Updated Profit" ]]

sum_df.sort_values(by=["client_id", "qty", "Updated Shipping Price", "Updated Total Price", "Updated Profit"], ascending=False).head(5)
# Out:
#        client_id    qty Updated Shipping Price Updated Total Price  \
# 35379      99984  33950          $2,395,512.00      $16,257,453.17
# 42337      99984   6145            $360,035.55       $1,074,078.87
# 43411      99984   2067             $53,824.68         $161,957.92
# 958        99984   1647             $25,594.38          $43,562.20
# 4895       99984    973             $12,668.46         $501,301.35
#
#        Updated Profit
# 35379  $-2,092,338.50
# 42337     $194,857.95
# 43411      $17,342.13
# 958        $21,740.40
# 4895     $-136,589.74

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
df['Total Price'] = df['Total Price'].astype(float)
df['Profit'] = df['Profit'].astype(float)
df['Shipping Price'] = df['Shipping Price'].astype(float)

df['Updated Total Price'] = df['Total Price'].apply(lambda x: f"${x:,.2f}")
df['Updated Profit'] = df['Profit'].apply(lambda x: f"${x:,.2f}")
df['Updated Shipping Price'] = df['Shipping Price'].apply(lambda x: f"${x:,.2f}")

sum_df = df[["client_id", "qty", "Updated Shipping Price", "Updated Total Price", "Updated Profit" ]]

sum_df.sort_values(by=["client_id", "qty", "Updated Shipping Price", "Updated Total Price", "Updated Profit"], ascending=False).head(5)
# Out:
#        client_id    qty Updated Shipping Price Updated Total Price  \
# 35379      99984  33950          $2,395,512.00      $16,257,453.17
# 42337      99984   6145            $360,035.55       $1,074,078.87
# 43411      99984   2067             $53,824.68         $161,957.92
# 958        99984   1647             $25,594.38          $43,562.20
# 4895       99984    973             $12,668.46         $501,301.35
#
#        Updated Profit
# 35379  $-2,092,338.50
# 42337     $194,857.95
# 43411      $17,342.13
# 958        $21,740.40
# 4895     $-136,589.74
